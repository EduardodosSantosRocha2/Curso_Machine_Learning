# %% [markdown]
# # Mensagem de Ola Mundo

# %%
print('ola mudo');
# Out:
# ola mudo

# %% [markdown]
# # input

# %%
nome = input("Qual é seu nome?");
print(nome);

# %% [markdown]
# ##Operadores Matematicos

# %%
vezes = 1*4;
div = 13/8;
resto = 50 % 34;
if vezes == 5 or div == 1.3:
  print("Vezes: {}\nDiv: {:.3f}\nResto: {}\n".format(vezes, div, resto));

elif vezes == 4 and div == 1.625:
  print('teste');

else:
  print('erro');
# Out:
# teste
