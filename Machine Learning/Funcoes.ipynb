# %%
def idadeEnome(idade, nome):
  print("Sua idade é: {}\nSeu nome é: {}\n".format(idade, nome));
  numaleatorio = idade*2;
  return numaleatorio;

# %%
print("Numale: {}\n".format( idadeEnome(8,"jose")));
# Out:
# Sua idade é: 8
# Seu nome é: jose
#
# Numale: 16
